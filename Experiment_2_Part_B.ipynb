# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevaprakash-S/24ADI006_24BAD048/blob/main/Experiment_2_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("24BAD048-Jeevaprakash")
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import pandas as pd
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

def create_model(act):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation=act),
        tf.keras.layers.Dense(64, activation=act),
        tf.keras.layers.Dense(10, activation="softmax")
    ])
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model
results = []

for act in ["sigmoid", "tanh", "relu"]:

    print("\nActivation:", act)

    model = create_model(act)

    history = model.fit(
        X_train,
        y_train,
        epochs=10,
        validation_split=0.2,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

    train_acc = history.history["accuracy"][-1]
    val_acc = history.history["val_accuracy"][-1]

    train_loss = history.history["loss"][-1]
    val_loss = history.history["val_loss"][-1]

    converge_epoch = history.history["val_loss"].index(
        min(history.history["val_loss"])
    ) + 1

    results.append([
        act,
        train_acc,
        val_acc,
        train_loss,
        val_loss,
        converge_epoch,
        test_acc
    ])
df = pd.DataFrame(results, columns=[
    "Activation",
    "Training Accuracy",
    "Validation Accuracy",
    "Training Loss",
    "Validation Loss",
    "Epochs to Converge",
    "Test Accuracy"
])

print("\nComparison of Activation Functions")
print(df)
# Out:
# 24BAD048-Jeevaprakash
#
# Activation: sigmoid
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8669 - loss: 0.5317 - val_accuracy: 0.9353 - val_loss: 0.2296
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9411 - loss: 0.1996 - val_accuracy: 0.9530 - val_loss: 0.1631
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9578 - loss: 0.1407 - val_accuracy: 0.9629 - val_loss: 0.1291
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9688 - loss: 0.1051 - val_accuracy: 0.9663 - val_loss: 0.1133
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9760 - loss: 0.0817 - val_accuracy: 0.9684 - val_loss: 0.1045
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9813 - loss: 0.0652 - val_accuracy: 0.9711 - val_loss: 0.0990
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9852 - loss: 0.0515 - val_accuracy: 0.9717 - val_loss: 0.0976
# Epoch 8/10
# ...
