# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevaprakash-S/24ADI006_24BAD048/blob/main/Experiment_2_Part_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment - 2**

# %% [markdown]
# # **Part A**

# %%
print("24BAD048 - Jeevaprakash S")
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)

sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

plt.figure(figsize=(8,5))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")
plt.title("Activation Functions")
plt.xlabel("x")
plt.ylabel("Output")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 24BAD048 - Jeevaprakash S

# %% [markdown]
# ### **Part B**

# %%
print("24BAD048-Jeevaprakash")
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import pandas as pd
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

def create_model(act):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation=act),
        tf.keras.layers.Dense(64, activation=act),
        tf.keras.layers.Dense(10, activation="softmax")
    ])
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model
results = []

for act in ["sigmoid", "tanh", "relu"]:

    print("\nActivation:", act)

    model = create_model(act)

    history = model.fit(
        X_train,
        y_train,
        epochs=10,
        validation_split=0.2,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

    train_acc = history.history["accuracy"][-1]
    val_acc = history.history["val_accuracy"][-1]

    train_loss = history.history["loss"][-1]
    val_loss = history.history["val_loss"][-1]

    converge_epoch = history.history["val_loss"].index(
        min(history.history["val_loss"])
    ) + 1

    results.append([
        act,
        train_acc,
        val_acc,
        train_loss,
        val_loss,
        converge_epoch,
        test_acc
    ])
df = pd.DataFrame(results, columns=[
    "Activation",
    "Training Accuracy",
    "Validation Accuracy",
    "Training Loss",
    "Validation Loss",
    "Epochs to Converge",
    "Test Accuracy"
])

print("\nComparison of Activation Functions")
print(df)
# Out:
# 24BAD048-Jeevaprakash
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Activation: sigmoid
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8680 - loss: 0.5338 - val_accuracy: 0.9356 - val_loss: 0.2266
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9414 - loss: 0.2002 - val_accuracy: 0.9528 - val_loss: 0.1630
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9583 - loss: 0.1419 - val_accuracy: 0.9617 - val_loss: 0.1349
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9682 - loss: 0.1071 - val_accuracy: 0.9652 - val_loss: 0.1170
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9759 - loss: 0.0834 - val_accuracy: 0.9685 - val_loss: 0.1051
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9809 - loss: 0.0669 - val_accuracy: 0.9694 - val_loss: 0.1019
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9843 - loss: 0.0540 - val_accuracy: 0.9718 - val_loss: 0.0967
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9875 - loss: 0.0433 - val_accuracy: 0.9735 - val_loss: 0.0888
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9899 - loss: 0.0350 - val_accuracy: 0.9729 - val_loss: 0.0898
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9919 - loss: 0.0284 - val_accuracy: 0.9731 - val_loss: 0.0906
#
# Activation: tanh
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9160 - loss: 0.2914 - val_accuracy: 0.9530 - val_loss: 0.1619
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9578 - loss: 0.1365 - val_accuracy: 0.9620 - val_loss: 0.1331
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9733 - loss: 0.0903 - val_accuracy: 0.9688 - val_loss: 0.1076
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9796 - loss: 0.0657 - val_accuracy: 0.9681 - val_loss: 0.0996
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9857 - loss: 0.0475 - val_accuracy: 0.9720 - val_loss: 0.0952
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9882 - loss: 0.0388 - val_accuracy: 0.9714 - val_loss: 0.0975
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9904 - loss: 0.0299 - val_accuracy: 0.9743 - val_loss: 0.0918
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9931 - loss: 0.0223 - val_accuracy: 0.9722 - val_loss: 0.1021
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9939 - loss: 0.0197 - val_accuracy: 0.9704 - val_loss: 0.1133
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9948 - loss: 0.0166 - val_accuracy: 0.9718 - val_loss: 0.1129
#
# Activation: relu
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9222 - loss: 0.2645 - val_accuracy: 0.9582 - val_loss: 0.1378
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9669 - loss: 0.1118 - val_accuracy: 0.9668 - val_loss: 0.1116
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9767 - loss: 0.0750 - val_accuracy: 0.9669 - val_loss: 0.1101
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9821 - loss: 0.0584 - val_accuracy: 0.9723 - val_loss: 0.0976
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9858 - loss: 0.0445 - val_accuracy: 0.9766 - val_loss: 0.0882
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9885 - loss: 0.0358 - val_accuracy: 0.9723 - val_loss: 0.1035
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9899 - loss: 0.0298 - val_accuracy: 0.9728 - val_loss: 0.1143
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9915 - loss: 0.0244 - val_accuracy: 0.9728 - val_loss: 0.1174
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9928 - loss: 0.0212 - val_accuracy: 0.9737 - val_loss: 0.1207
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9929 - loss: 0.0201 - val_accuracy: 0.9743 - val_loss: 0.1146
#
# Comparison of Activation Functions
#   Activation  Training Accuracy  Validation Accuracy  Training Loss  \
# 0    sigmoid           0.991896             0.973083       0.028412
# 1       tanh           0.994833             0.971750       0.016571
# 2       relu           0.992938             0.974250       0.020059
#
#    Validation Loss  Epochs to Converge  Test Accuracy
# 0         0.090644                   8         0.9764
# 1         0.112929                   7         0.9734
# 2         0.114604                   5         0.9734

# %% [markdown]
# ### **Part C**

# %%
print("24BAD048-Jeevaprakash")
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import pandas as pd
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

optimizers = {
    "SGD": tf.keras.optimizers.SGD(),
    "Momentum": tf.keras.optimizers.SGD(momentum=0.9),
    "RMSProp": tf.keras.optimizers.RMSprop(),
    "Adam": tf.keras.optimizers.Adam()
}

histories = {}
results = []
for name, optimizer in optimizers.items():

    print("\nTraining using", name)

    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
    ])
    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    history = model.fit(
        x_train,
        y_train,
        epochs=5,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    histories[name] = history
    train_loss = history.history['loss'][-1]
    val_loss = history.history['val_loss'][-1]

    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    convergence = history.history['val_loss'].index(
        min(history.history['val_loss'])
    ) + 1

    results.append([
        name,
        train_loss,
        val_loss,
        convergence,
        train_acc,
        val_acc
    ])
df = pd.DataFrame(results, columns=[
    "Optimizer",
    "Training Loss",
    "Validation Loss",
    "Convergence Epoch",
    "Training Accuracy",
    "Validation Accuracy"
])

print("\nOptimizer Comparison\n")
print(df)

plt.figure(figsize=(10,5))

for name in optimizers:
    plt.plot(histories[name].history['accuracy'], label=name)

plt.title("Training Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))

for name in optimizers:
    plt.plot(histories[name].history['val_accuracy'], label=name)

plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))

for name in optimizers:
    plt.plot(histories[name].history['loss'], label=name)

plt.title("Training Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))

for name in optimizers:
    plt.plot(histories[name].history['val_loss'], label=name)

plt.title("Validation Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 24BAD048-Jeevaprakash
#
# Training using SGD
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8110 - loss: 0.7278 - val_accuracy: 0.9030 - val_loss: 0.3451
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9080 - loss: 0.3251 - val_accuracy: 0.9233 - val_loss: 0.2725
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9234 - loss: 0.2705 - val_accuracy: 0.9322 - val_loss: 0.2397
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9334 - loss: 0.2353 - val_accuracy: 0.9398 - val_loss: 0.2119
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9402 - loss: 0.2083 - val_accuracy: 0.9448 - val_loss: 0.1968
#
# Training using Momentum
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9067 - loss: 0.3155 - val_accuracy: 0.9532 - val_loss: 0.1570
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9595 - loss: 0.1337 - val_accuracy: 0.9657 - val_loss: 0.1149
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9722 - loss: 0.0940 - val_accuracy: 0.9718 - val_loss: 0.1008
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9779 - loss: 0.0715 - val_accuracy: 0.9712 - val_loss: 0.0968
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9822 - loss: 0.0562 - val_accuracy: 0.9737 - val_loss: 0.0905
#
# Training using RMSProp
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9216 - loss: 0.2691 - val_accuracy: 0.9554 - val_loss: 0.1489
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9649 - loss: 0.1196 - val_accuracy: 0.9665 - val_loss: 0.1160
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9743 - loss: 0.0858 - val_accuracy: 0.9728 - val_loss: 0.0988
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9812 - loss: 0.0655 - val_accuracy: 0.9746 - val_loss: 0.0959
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9846 - loss: 0.0523 - val_accuracy: 0.9722 - val_loss: 0.1118
#
# Training using Adam
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9225 - loss: 0.2659 - val_accuracy: 0.9635 - val_loss: 0.1237
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9668 - loss: 0.1112 - val_accuracy: 0.9684 - val_loss: 0.1099
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9764 - loss: 0.0769 - val_accuracy: 0.9711 - val_loss: 0.0953
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9819 - loss: 0.0571 - val_accuracy: 0.9700 - val_loss: 0.0989
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9856 - loss: 0.0453 - val_accuracy: 0.9732 - val_loss: 0.0927
#
# Optimizer Comparison
#
#   Optimizer  Training Loss  Validation Loss  Convergence Epoch  \
# 0       SGD       0.208292         0.196757                  5
# 1  Momentum       0.056190         0.090521                  5
# 2   RMSProp       0.052333         0.111798                  4
# 3      Adam       0.045348         0.092721                  5
#
#    Training Accuracy  Validation Accuracy
# 0           0.940250             0.944750
# 1           0.982188             0.973750
# 2           0.984646             0.972167
# 3           0.985583             0.973250

# %% [markdown]
# ### **Part D**

# %%
print("24BAD048_Jeevaprakash S")
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10)
])

model.save("/content/drive/MyDrive/ann_model.h5")

print("Model Saved Successfully")
# Out:
# 24BAD048_Jeevaprakash S
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model Saved Successfully
